# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/imdb-data/IMDB-Movie-Data.csv')

# %%
# 1. Show the first 10 rows of the dataset
df.head(10)

# %%
# 2. Show the last 10 rows of the dataset
df.tail(10)

# %%
# 3. Display the number of rows and columns in the dataset
df.shape
print('Number of rows:',data.shape[0])
print('Number of columns:',data.shape[1])

# %%
# 4. Display general information about the dataset
df.info()

# %%
# 5. Check for null values
df.isnull().sum()

# %%
# 6. Drop missing values
df = df.dropna(axis=0)
sns.heatmap(data.isnull())
plt.show()

# %%
# 7. Check for duplicates
duplicates = df.duplicated().any()
print("Are there any duplicated values in data?",dup_data)

# %%
# 8. General statistics about the dataset
df.describe()

# %%
# 9. Movies with a runtime of more than 180 minutes
df[df['Runtime (Minutes)']>=180]['Title']

# %%
# 10. Year with the highest voting
sns.barplot(x='Year',y='Votes',data=df)
plt.title("Votes by year")
plt.show()

# %%
# 11. Year with the highest revenue
sns.barplot(x='Year',y='Revenue (Millions)',data=df)
plt.title("Revenue by year")
plt.show()

# %%
# 12. Average rating for each director
df.groupby('Director')['Rating'].mean().sort_values(ascending=False)

# %%
# 13. Top 10 movies with the longest duration
longest_duration = data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]. \
set_index('Title')
sns.barplot(longest_duration['Runtime (Minutes)'],y=longest_duration.index)
plt.title('Top 10 movies with the longest duration')
plt.show()

# %%
# 14. Number of movies per year
sns.countplot(x='Year',data=df)
plt.title("Number of movies per year")

# %%
# 15. Most popular movie (Higest revenue)
df[df['Revenue (Millions)'].max() == df['Revenue (Millions)']]['Title']

# %%
# 16. Top 10 highest rated movies and their director
top_10_rated=df.nlargest(10,'Rating')[['Title','Rating','Director']].set_index('Title')
top_10

sns.barplot(top_10_rated['Rating'],top_10.index)
plt.title("Top 10 highest rated movies")
plt.show()

# %%
# 17. Top 10 highest revenue movies
top_10_rev = data.nlargest(10,'Revenue (Millions)')[['Title','Director','Revenue (Millions)']].set_index('Title')
top_10_rev

sns.barplot(top_10_rev['Revenue (Millions)'],top_10_rev.index)
plt.title("Top 10 highest revenue movies")
plt.show()

# %%
# 18. Average movie rating per year
years_rating = data.groupby('Year')['Year','Rating'].mean().\
sort_values(by='Rating',ascending=False).set_index('Year')

years_rating

plt.figure(figsize=(10,5))
sns.barplot(years_rating.index,years_rating['Rating'])
plt.show()

# %%
# 19. Does rating affect revenue?
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=df)
plt.show()

print("Does rating affect revenue? Apparently, yes.")

# %%
# 20. Classify movies based on ratings: Excellent, Good, Average
def rating(rating):
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

df['rating_cat'] = df['Rating'].apply(rating)

# %%
# 21. Number of movies by genre
genre_list = []
for value in df['Genre']:
    genre_list.append(value.split(','))
    
df['temp'] = genre_list

genre = input("Enter movie genre to count: ").title()
count = 0
for value in df['temp']:
    if genre in value:
        count = count+1
print("Total count: ",count)
